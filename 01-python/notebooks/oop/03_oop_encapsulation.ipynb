# %% [markdown]
# # Python OOP: Encapsulation and Access Modifiers
#
# Encapsulation is about bundling data and methods inside a class and protecting them from unauthorized access.

# %% [markdown]
# ## 1. Access Modifiers
# Python uses naming conventions to signal visibility:
#
# | Modifier | Convention | Access Level |
# | :--- | :--- | :--- |
# | **Public** | `name` | Everywhere |
# | **Protected** | `_name` | Internal & Subclasses |
# | **Private** | `__name` | Class only (Name Mangling) |

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner          # Public
        self._account_type = "Basic" # Protected
        self.__balance = balance     # Private

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Amount deposited. New balance: {self.__balance}")

    def display_balance(self):
        print(f"Account Balance: {self.__balance}")

acc = BankAccount("Himanshu", 5000)

print(f"Owner: {acc.owner}") # Public access
print(f"Type: {acc._account_type}") # Protected access (Internal use)

try:
    print(acc.__balance)
except AttributeError:
    print("AttributeError: Private '__balance' is not accessible from outside!")

acc.display_balance() # Correct way to access internal data

# %% [markdown]
# ## 2. Abstraction (Hiding Complexity)
# Abstraction focuses on *what* an object does rather than *how* it does it. We use the `abc` module to define Abstract Base Classes.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Vroom! Car engine started."

class Truck(Vehicle):
    def start_engine(self):
        return "Rumble! Truck engine started."

fleet = [Car(), Truck()]
for v in fleet:
    print(v.start_engine())
