# %% [markdown]
# # Python Exception Handling
#
# Exception handling allows you to handle errors gracefully. The core blocks are `try`, `except`, `else`, and `finally`.

# %% [markdown]
# ## 1. Basic `try...except`

# %%
try:
    # This will cause a ZeroDivisionError
    result = 10 / 0
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")
# Out:
# Error: You cannot divide by zero!

# %% [markdown]
# ## 2. Handling Multiple Exceptions
# You can define multiple `except` blocks to handle different types of errors.

# %%
try:
    number = int("abc")  # This causes a ValueError
except ValueError:
    print("Invalid input: Please enter a numeric string.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ## 3. The `else` and `finally` Blocks
# - `else`: Runs only if no errors occurred.
# - `finally`: Runs regardless of what happened.

# %%
try:
    x = 10
    y = 2
    print(f"Dividing {x} by {y}...")
    result = x / y
except ZeroDivisionError:
    print("Oops! Division by zero.")
else:
    print(f"Success! Result is {result}")
finally:
    print("This runs no matter what (Great for cleaning up resources!)")

# %% [markdown]
# ## 4. Raising Exceptions Manually

# %%
age = -1
try:
    if age < 0:
        raise ValueError("Age cannot be negative")
except ValueError as ve:
    print(f"Caught intentional error: {ve}")
